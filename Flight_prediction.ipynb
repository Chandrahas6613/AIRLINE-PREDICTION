# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotib
# !pip install seaborn
# !pip  install openpyxl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: pandas in /home/akanksh/.local/lib/python3.11/site-packages (2.2.2)
# Ignoring numpy: markers 'python_version < "3.11"' don't match your environment
# Requirement already satisfied: tzdata>=2022.7 in /home/akanksh/.local/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/akanksh/.local/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/akanksh/.local/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in /home/akanksh/.local/lib/python3.11/site-packages (2.1.1)
# ERROR: Could not find a version that satisfies the requirement matplotib
# ERROR: No matching distribution found for matplotib
# Requirement already satisfied: seaborn in /home/akanksh/.local/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: pandas>=1.2 in /home/akanksh/.local/lib/python3.11/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/akanksh/.local/lib/python3.11/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/akanksh/.local/lib/python3.11/site-packages (from seaborn) (2.1.1)
# Ignoring importlib-resources: markers 'python_version < "3.10"' don't match your environment
# Requirement already satisfied: python-dateutil>=2.7 in /home/akanksh/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/akanksh/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/akanksh/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/akanksh/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (20.9)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/akanksh/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Ignoring numpy: markers 'python_version < "3.11"' don't match your environment
# Requirement already satisfied: tzdata>=2022.7 in /home/akanksh/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /home/akanksh/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: openpyxl in /home/akanksh/.local/lib/python3.11/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /home/akanksh/.local/lib/python3.11/site-packages (from openpyxl) (1.1.0)

# %%
flight = pd.read_excel('/home/akanksh/BAHULYA/FLIGHT_PRICE_PREDICTION-main/Data_Train.xlsx')
flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flight.shape
# Out:
# (10683, 11)

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
flight['Duration'].value_counts()
# Out:
# Duration
# 2h 50m     550
# 1h 30m     386
# 2h 55m     337
# 2h 45m     337
# 2h 35m     329
#           ...
# 30h 10m      1
# 31h 30m      1
# 42h 5m       1
# 4h 10m       1
# 5m           1
# Name: count, Length: 368, dtype: int64

# %%
flight.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
flight.dropna(inplace=True)
flight.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flight['Journey_Day'] = pd.to_datetime(flight.Date_of_Journey , format = '%d/%m/%Y').dt.day
flight['Journey_Month'] = pd.to_datetime(flight.Date_of_Journey , format = '%d/%m/%Y').dt.month
flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Day  Journey_Month
# 0           24              3
# 1            1              5
# 2            9              6
# 3           12              5
# 4            1              3

# %%
flight['Dep_hour'] = pd.to_datetime(flight.Dep_Time ).dt.hour
flight['Dep_Minute'] = pd.to_datetime(flight.Dep_Time ).dt.minute
flight.head()
# Out:
# /tmp/ipykernel_12717/2517023688.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight['Dep_hour'] = pd.to_datetime(flight.Dep_Time ).dt.hour
# /tmp/ipykernel_12717/2517023688.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight['Dep_Minute'] = pd.to_datetime(flight.Dep_Time ).dt.minute
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Day  Journey_Month  Dep_hour  Dep_Minute
# 0           24              3        22          20
# 1            1              5         5          50
# 2            9              6         9          25
# 3           12              5        18           5
# 4            1              3        16          50

# %%
flight['Arrival_hour'] = pd.to_datetime(flight.Arrival_Time ).dt.hour
flight['Arrival_Minute'] = pd.to_datetime(flight.Arrival_Time ).dt.minute
flight.head()
# Out:
# /tmp/ipykernel_12717/4244514515.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight['Arrival_hour'] = pd.to_datetime(flight.Arrival_Time ).dt.hour
# /tmp/ipykernel_12717/4244514515.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight['Arrival_Minute'] = pd.to_datetime(flight.Arrival_Time ).dt.minute
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Day  Journey_Month  Dep_hour  Dep_Minute  Arrival_hour  \
# 0           24              3        22          20             1
# 1            1              5         5          50            13
# 2            9              6         9          25             4
# 3           12              5        18           5            23
# 4            1              3        16          50            21
#
#    Arrival_Minute
# 0              10
# 1              15
# 2              25
# 3              30
# 4              35

# %%
flight.drop(columns=['Dep_Time' , 'Date_of_Journey'],inplace=True)

# %%
flight.drop(columns='Arrival_Time',inplace=True)

# %%
flight.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  Journey_Day  Journey_Month  Dep_hour  \
# 0    non-stop         No info   3897           24              3        22
# 1     2 stops         No info   7662            1              5         5
# 2     2 stops         No info  13882            9              6         9
# 3      1 stop         No info   6218           12              5        18
# 4      1 stop         No info  13302            1              3        16
#
#    Dep_Minute  Arrival_hour  Arrival_Minute
# 0          20             1              10
# 1          50            13              15
# 2          25             4              25
# 3           5            23              30
# 4          50            21              35

# %%
duration = list(flight.Duration)

for i in range(len(duration)):
    if len(duration[i].split()) != 2:
        if 'h' in duration[i]:
            duration[i] = duration[i] + ' 0m'
        else:
            duration[i] = '0h ' + duration[i]
            
duration
duration_hour=[]
duration_minute=[]

for i in range(len(duration)):
    duration_hour.append(int(duration[i].split(sep='h')[0] ))
    duration_minute.append(int( duration[i].split('m')[0].split()[-1] ))

# %%
flight['Duration_Hour'] = duration_hour
flight['Duration_Minute'] = duration_minute

# %%
flight.drop(columns='Duration',inplace=True)

# %%
flight.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0         No info   3897           24              3        22          20
# 1         No info   7662            1              5         5          50
# 2         No info  13882            9              6         9          25
# 3         No info   6218           12              5        18           5
# 4         No info  13302            1              3        16          50
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute
# 0             1              10              2               50
# 1            13              15              7               25
# 2             4              25             19                0
# 3            23              30              5               25
# 4            21              35              4               45

# %%
flight['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
sns.catplot(y='Price' , x='Airline' , data = flight.sort_values('Price',ascending=False) , kind='boxen' , height=6 , aspect=3)

# %%
Airline = flight['Airline']
Airline = pd.get_dummies(Airline , drop_first=True)
Airline.head()
# Out:
#    Air India  GoAir  IndiGo  Jet Airways  Jet Airways Business  \
# 0      False  False    True        False                 False
# 1       True  False   False        False                 False
# 2      False  False   False         True                 False
# 3      False  False    True        False                 False
# 4      False  False    True        False                 False
#
#    Multiple carriers  Multiple carriers Premium economy  SpiceJet  Trujet  \
# 0              False                              False     False   False
# 1              False                              False     False   False
# 2              False                              False     False   False
# 3              False                              False     False   False
# 4              False                              False     False   False
#
#    Vistara  Vistara Premium economy
# 0    False                    False
# 1    False                    False
# 2    False                    False
# 3    False                    False
# 4    False                    False

# %%
flight['Source'].value_counts()
# Out:
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
sns.catplot(y='Price' , x='Source' , data = flight.sort_values('Price',ascending=False) , kind='boxen' , height=6 , aspect=3)

# %%
flight['Source'].value_counts()
# Out:
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
Source = flight[['Source']]

Source = pd.get_dummies(Source , drop_first=True)
Source.head()
# Out:
#    Source_Chennai  Source_Delhi  Source_Kolkata  Source_Mumbai
# 0           False         False           False          False
# 1           False         False            True          False
# 2           False          True           False          False
# 3           False         False            True          False
# 4           False         False           False          False

# %%
flight['Destination'].value_counts()
# Out:
# Destination
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
Destination = flight[['Destination']]

Destination = pd.get_dummies(Destination , drop_first=True)
Destination.head()
# Out:
#    Destination_Cochin  Destination_Delhi  Destination_Hyderabad  \
# 0               False              False                  False
# 1               False              False                  False
# 2                True              False                  False
# 3               False              False                  False
# 4               False              False                  False
#
#    Destination_Kolkata  Destination_New Delhi
# 0                False                   True
# 1                False                  False
# 2                False                  False
# 3                False                  False
# 4                False                   True

# %%
flight['Route']
# Out:
# 0                    BLR → DEL
# 1        CCU → IXR → BBI → BLR
# 2        DEL → LKO → BOM → COK
# 3              CCU → NAG → BLR
# 4              BLR → NAG → DEL
#                  ...
# 10678                CCU → BLR
# 10679                CCU → BLR
# 10680                BLR → DEL
# 10681                BLR → DEL
# 10682    DEL → GOI → BOM → COK
# Name: Route, Length: 10682, dtype: object

# %%
flight.drop(columns=['Route','Additional_Info'],axis=1 , inplace=True)

# %%
flight.head()
# Out:
#        Airline    Source Destination Total_Stops  Price  Journey_Day  \
# 0       IndiGo  Banglore   New Delhi    non-stop   3897           24
# 1    Air India   Kolkata    Banglore     2 stops   7662            1
# 2  Jet Airways     Delhi      Cochin     2 stops  13882            9
# 3       IndiGo   Kolkata    Banglore      1 stop   6218           12
# 4       IndiGo  Banglore   New Delhi      1 stop  13302            1
#
#    Journey_Month  Dep_hour  Dep_Minute  Arrival_hour  Arrival_Minute  \
# 0              3        22          20             1              10
# 1              5         5          50            13              15
# 2              6         9          25             4              25
# 3              5        18           5            23              30
# 4              3        16          50            21              35
#
#    Duration_Hour  Duration_Minute
# 0              2               50
# 1              7               25
# 2             19                0
# 3              5               25
# 4              4               45

# %%
flight['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
flight.replace( { 'non-stop':0 , '1 stop':1 , '2 stops':2 , '3 stops':3 ,'4 stops':4 } ,inplace=True)
# Out:
# /tmp/ipykernel_12717/1174757405.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   flight.replace( { 'non-stop':0 , '1 stop':1 , '2 stops':2 , '3 stops':3 ,'4 stops':4 } ,inplace=True)

# %%
flight.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Journey_Day  \
# 0       IndiGo  Banglore   New Delhi            0   3897           24
# 1    Air India   Kolkata    Banglore            2   7662            1
# 2  Jet Airways     Delhi      Cochin            2  13882            9
# 3       IndiGo   Kolkata    Banglore            1   6218           12
# 4       IndiGo  Banglore   New Delhi            1  13302            1
#
#    Journey_Month  Dep_hour  Dep_Minute  Arrival_hour  Arrival_Minute  \
# 0              3        22          20             1              10
# 1              5         5          50            13              15
# 2              6         9          25             4              25
# 3              5        18           5            23              30
# 4              3        16          50            21              35
#
#    Duration_Hour  Duration_Minute
# 0              2               50
# 1              7               25
# 2             19                0
# 3              5               25
# 4              4               45

# %%
flight = pd.concat( [flight , Airline ,Source , Destination] , axis=1)

# %%
flight.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Journey_Day  \
# 0       IndiGo  Banglore   New Delhi            0   3897           24
# 1    Air India   Kolkata    Banglore            2   7662            1
# 2  Jet Airways     Delhi      Cochin            2  13882            9
# 3       IndiGo   Kolkata    Banglore            1   6218           12
# 4       IndiGo  Banglore   New Delhi            1  13302            1
#
#    Journey_Month  Dep_hour  Dep_Minute  Arrival_hour  ...  \
# 0              3        22          20             1  ...
# 1              5         5          50            13  ...
# 2              6         9          25             4  ...
# 3              5        18           5            23  ...
# 4              3        16          50            21  ...
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False         False           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False         False            True
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False               False              False
# 1          False               False              False
# 2          False                True              False
# 3          False               False              False
# 4          False               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True
#
# [5 rows x 33 columns]

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
flight.head()
# Out:
#        Airline    Source Destination  Total_Stops  Price  Journey_Day  \
# 0       IndiGo  Banglore   New Delhi            0   3897           24
# 1    Air India   Kolkata    Banglore            2   7662            1
# 2  Jet Airways     Delhi      Cochin            2  13882            9
# 3       IndiGo   Kolkata    Banglore            1   6218           12
# 4       IndiGo  Banglore   New Delhi            1  13302            1
#
#    Journey_Month  Dep_hour  Dep_Minute  Arrival_hour  Arrival_Minute  \
# 0              3        22          20             1              10
# 1              5         5          50            13              15
# 2              6         9          25             4              25
# 3              5        18           5            23              30
# 4              3        16          50            21              35
#
#    Duration_Hour  Duration_Minute  Air India  GoAir  IndiGo  Jet Airways  \
# 0              2               50      False  False    True        False
# 1              7               25       True  False   False        False
# 2             19                0      False  False   False         True
# 3              5               25      False  False    True        False
# 4              4               45      False  False    True        False
#
#    Jet Airways Business  Multiple carriers  Multiple carriers Premium economy  \
# 0                 False              False                              False
# 1                 False              False                              False
# 2                 False              False                              False
# 3                 False              False                              False
# 4                 False              False                              False
#
#    SpiceJet  Trujet  Vistara  Vistara Premium economy  Source_Chennai  \
# 0     False   False    False                    False           False
# 1     False   False    False                    False           False
# 2     False   False    False                    False           False
# 3     False   False    False                    False           False
# 4     False   False    False                    False           False
#
#    Source_Delhi  Source_Kolkata  Source_Mumbai  Destination_Cochin  \
# 0         False           False          False               False
# 1         False            True          False               False
# 2          True           False          False                True
# 3         False            True          False               False
# 4         False           False          False               False
#
#    Destination_Delhi  Destination_Hyderabad  Destination_Kolkata  \
# 0              False                  False                False
# 1              False                  False                False
# 2              False                  False                False
# 3              False                  False                False
# 4              False                  False                False
#
#    Destination_New Delhi
# 0                   True
# 1                  False
# 2                  False
# 3                  False
# 4                   True

# %%
flight.drop(columns = [ 'Airline' , 'Source' , 'Destination' ] , inplace=True)

# %%
flight.head()
# Out:
#    Total_Stops  Price  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0            0   3897           24              3        22          20
# 1            2   7662            1              5         5          50
# 2            2  13882            9              6         9          25
# 3            1   6218           12              5        18           5
# 4            1  13302            1              3        16          50
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute  Air India  \
# 0             1              10              2               50      False
# 1            13              15              7               25       True
# 2             4              25             19                0      False
# 3            23              30              5               25      False
# 4            21              35              4               45      False
#
#    GoAir  IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0  False    True        False                 False              False
# 1  False   False        False                 False              False
# 2  False   False         True                 False              False
# 3  False    True        False                 False              False
# 4  False    True        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  \
# 0                              False     False   False    False
# 1                              False     False   False    False
# 2                              False     False   False    False
# 3                              False     False   False    False
# 4                              False     False   False    False
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False         False           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False         False            True
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False               False              False
# 1          False               False              False
# 2          False                True              False
# 3          False               False              False
# 4          False               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True

# %%
flight.shape
# Out:
# (10682, 30)

# %% [markdown]
# ## Test Data

# %%
flight_test = pd.read_excel('/home/akanksh/BAHULYA/FLIGHT_PRICE_PREDICTION-main/Data_Train.xlsx')
flight_test.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
print("-"*50)
print("Shape")
print(flight_test.shape)

print("-"*50)
print("Info")
print(flight_test.info())

print("-"*50)
print("Duration count values")
print(flight_test['Duration'].value_counts())

print("-"*50)
print("Check null value")
print(flight_test.isnull().sum())

print("-"*50)
print("Drop null value rows")
flight_test.dropna(inplace=True)

print("-"*50)
print("Check null values")
print(flight_test.isnull().sum())

print("-"*50)
print("Fetch journey day and month from Date_of_Journey")
flight_test['Journey_Day'] = pd.to_datetime(flight_test.Date_of_Journey , format = '%d/%m/%Y').dt.day
flight_test['Journey_Month'] = pd.to_datetime(flight_test.Date_of_Journey , format = '%d/%m/%Y').dt.month
print(flight_test.head())

print("-"*50)
print("Fetch Departure hours and minutes from Dep_Time")
flight_test['Dep_hour'] = pd.to_datetime(flight_test.Dep_Time ).dt.hour
flight_test['Dep_Minute'] = pd.to_datetime(flight_test.Dep_Time ).dt.minute
print(flight_test.head())

print("-"*50)
print("Drop Dep_time and Date_of_Journey columns")
flight_test.drop(columns=['Dep_Time' , 'Date_of_Journey'],inplace=True)

print("-"*50)
print("Fetch journey hours and minutes from Arrival_Time")
flight_test['Arrival_hour'] = pd.to_datetime(flight_test.Arrival_Time ).dt.hour
flight_test['Arrival_Minute'] = pd.to_datetime(flight_test.Arrival_Time ).dt.minute
print(flight_test.head())

print("-"*50)
print("Drop Arrival_Time columns")
flight_test.drop(columns='Arrival_Time',inplace=True)

print("-"*50)
print("Fetch  hours and minutes from Durations")
duration = list(flight_test.Duration)

for i in range(len(duration)):
    if len(duration[i].split()) != 2:
        if 'h' in duration[i]:
            duration[i] = duration[i] + ' 0m'
        else:
            duration[i] = '0h ' + duration[i]
            
duration
duration_hour=[]
duration_minute=[]

for i in range(len(duration)):
    duration_hour.append(int(duration[i].split(sep='h')[0] ))
    duration_minute.append(int( duration[i].split('m')[0].split()[-1] ))

flight_test['Duration_Hour'] = duration_hour
flight_test['Duration_Minute'] = duration_minute
flight_test.drop(columns='Duration',inplace=True)

print("-"*50)
print("Count Airline values")
print(flight_test['Airline'].value_counts())


print("-"*50)
print("OneHotEncoder on Airline Column")
Airline = flight_test['Airline']
Airline = pd.get_dummies(Airline , drop_first=True)
print(Airline.head())

print("-"*50)
print("Count Source values")
print(flight_test['Source'].value_counts())


print("-"*50)
print("Count Source values")
print(flight_test['Source'].value_counts())

print("-"*50)
print("OneHotEncoder on Source Column")
Source = flight_test[['Source']]
Source = pd.get_dummies(Source , drop_first=True)
print(Source.head())

print("-"*50)
print("Count Destination values")
print(flight_test['Destination'].value_counts())

print("-"*50)
print("OneHotEncoder on Destination Column")
Destination = flight_test[['Destination']]
Destination = pd.get_dummies(Destination , drop_first=True)
print(Destination.head())

print("-"*50)
print("Show route")
print(flight_test['Route'])

print("-"*50)
print("Drop Route and Additional_Info")
flight_test.drop(columns=['Route','Additional_Info'],axis=1 , inplace=True)

print("-"*50)
print("Cout Total_Stops")
print(flight_test['Total_Stops'].value_counts())

print("-"*50)
print("Normalize total stops")
flight_test.replace( { 'non-stop':0 , '1 stop':1 , '2 stops':2 , '3 stops':3 ,'4 stops':4 } ,inplace=True)

print("-"*50)
print("Concate flight, airline, source and destionation")
flight_test = pd.concat( [flight_test , Airline ,Source , Destination] , axis=1)

print("-"*50)
print("Show all rows and columns")
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

print("-"*50)
print("Drop Airline, Source and Destination")
flight_test.drop(columns = [ 'Airline' , 'Source' , 'Destination' ] , inplace=True)

print("-"*50)
print("Show head")
print(flight_test.head())

print("-"*50)
print("Shape")
print(flight_test.shape)
# Out:
# --------------------------------------------------
# Shape
# (10683, 11)
# --------------------------------------------------
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB
# None
# --------------------------------------------------
# Duration count values
# Duration
# 2h 50m     550
# 1h 30m     386
# 2h 55m     337
# 2h 45m     337
# 2h 35m     329
# 3h         261
# 2h 20m     238
# 2h 30m     220
# 2h 40m     158
# 2h 15m     135
# 1h 25m     135
# 2h 25m      98
# 13h 30m     97
# 13h 20m     89
# 3h 15m      88
# 7h 30m      86
# 9h 30m      85
# 8h 40m      81
# 7h 15m      79
# 3h 5m       78
# 5h 30m      72
# 7h 35m      71
# 8h          68
# 7h 5m       65
# 9h          64
# 9h 50m      64
# 5h          63
# 11h 45m     62
# 5h 15m      62
# 11h         62
# 1h 20m      61
# 14h 25m     61
# 6h 35m      60
# 22h 55m     57
# 12h 10m     57
# 10h 30m     57
# 12h 45m     56
# 5h 45m      54
# 16h 5m      53
# 11h 30m     52
# 12h 30m     52
# 7h 20m      52
# 15h 10m     51
# 4h 55m      51
# 8h 25m      50
# 10h 15m     50
# 10h         49
# 12h         49
# 10h 25m     49
# 12h 15m     48
# 6h 15m      47
# 11h 5m      45
# 5h 20m      45
# 26h 55m     44
# 9h 15m      42
# 14h 5m      42
# 8h 55m      42
# 13h         42
# 9h 35m      41
# 20h 10m     41
# 9h 20m      41
# 17h 5m      40
# 23h 40m     40
# 3h 10m      40
# 26h 35m     39
# 21h 15m     39
# 6h 30m      38
# 5h 5m       38
# 14h 35m     38
# 27h 35m     38
# 6h 25m      37
# 23h 50m     37
# 13h 25m     36
# 13h 15m     36
# 11h 15m     36
# 18h 45m     36
# 14h         36
# 8h 30m      36
# 12h 25m     36
# 15h 20m     35
# 13h 50m     35
# 4h 50m      35
# 15h 25m     35
# 4h 30m      35
# 25h 45m     35
# 21h 35m     35
# 27h 20m     34
# 8h 20m      34
# 18h 20m     33
# 15h 30m     33
# 16h 45m     33
# 27h         32
# 14h 20m     31
# 12h 20m     31
# 7h 45m      31
# 12h 35m     31
# 5h 25m      31
# 8h 10m      30
# 5h 55m      30
# 23h 30m     30
# 24h 45m     30
# 15h         30
# 23h 15m     30
# 21h 25m     30
# 26h 10m     29
# 10h 40m     29
# 14h 30m     29
# 10h 20m     29
# 26h 20m     29
# 6h 5m       29
# 6h 20m      29
# 9h 5m       29
# 19h 55m     28
# 9h 45m      28
# 29h 20m     28
# 16h 15m     28
# 13h 55m     28
# 22h         27
# 26h         27
# 24h         27
# 5h 10m      27
# 7h 40m      27
# 6h          26
# 19h 25m     26
# 14h 55m     26
# 9h 10m      26
# 12h 55m     26
# 5h 35m      25
# 22h 5m      25
# 28h 50m     25
# 8h 35m      25
# 6h 10m      25
# 7h 50m      24
# 24h 55m     24
# 11h 25m     24
# 15h 40m     24
# 7h 55m      24
# 1h 15m      24
# 16h 50m     24
# 23h         24
# 24h 35m     23
# 10h 10m     23
# 6h 40m      23
# 11h 50m     23
# 4h 40m      23
# 3h 40m      23
# 23h 35m     23
# 22h 45m     22
# 16h 55m     22
# 22h 30m     22
# 28h 20m     22
# 24h 50m     22
# 20h         22
# 23h 10m     22
# 14h 50m     21
# 27h 5m      21
# 11h 55m     21
# 4h 35m      21
# 25h 30m     21
# 7h          21
# 5h 40m      21
# 23h 45m     21
# 20h 55m     21
# 13h 45m     21
# 11h 40m     20
# 25h 50m     20
# 24h 30m     20
# 12h 40m     20
# 10h 55m     20
# 17h 25m     20
# 8h 15m      20
# 21h 20m     19
# 12h 5m      19
# 14h 45m     19
# 25h 55m     19
# 15h 55m     19
# 26h 50m     19
# 16h         19
# 20h 20m     19
# 4h 25m      19
# 22h 10m     18
# 21h 40m     18
# 27h 10m     17
# 24h 40m     17
# 18h 10m     17
# 18h 25m     17
# 20h 15m     17
# 25h 20m     17
# 6h 55m      17
# 10h 35m     17
# 8h 5m       17
# 22h 15m     17
# 20h 25m     16
# 26h 30m     16
# 16h 10m     16
# 24h 10m     16
# 19h 5m      15
# 30h 30m     15
# 27h 40m     15
# 1h 35m      15
# 22h 35m     15
# 27h 45m     15
# 14h 10m     14
# 19h 30m     14
# 26h 40m     14
# 30h 20m     14
# 13h 10m     14
# 25h 35m     14
# 10h 45m     14
# 23h 20m     14
# 25h 5m      14
# 10h 50m     13
# 18h         13
# 38h         13
# 9h 25m      13
# 25h 40m     13
# 5h 50m      13
# 8h 45m      13
# 21h 5m      12
# 28h 5m      12
# 38h 15m     12
# 29h 35m     12
# 21h 10m     12
# 17h 45m     12
# 19h 40m     12
# 4h          12
# 20h 35m     12
# 25h         12
# 15h 15m     12
# 23h 5m      11
# 22h 25m     11
# 16h 35m     11
# 17h 20m     11
# 14h 15m     11
# 28h         11
# 17h 55m     11
# 33h 15m     11
# 11h 35m     11
# 19h 15m     10
# 4h 45m      10
# 9h 40m      10
# 17h 35m     10
# 29h 5m       9
# 19h          9
# 16h 25m      9
# 14h 40m      9
# 25h 25m      9
# 25h 15m      9
# 26h 15m      9
# 15h 5m       9
# 21h 55m      9
# 23h 55m      9
# 16h 20m      9
# 17h 30m      8
# 37h 20m      8
# 19h 45m      8
# 37h 25m      8
# 21h 45m      8
# 15h 45m      8
# 4h 5m        8
# 20h 45m      8
# 26h 25m      8
# 29h 55m      8
# 8h 50m       8
# 24h 15m      7
# 30h 40m      7
# 28h 15m      7
# 18h 30m      7
# 19h 10m      7
# 17h 15m      7
# 18h 50m      7
# 15h 35m      7
# 6h 45m       7
# 16h 40m      7
# 11h 20m      7
# 36h 10m      6
# 21h          6
# 29h 50m      5
# 17h 40m      5
# 38h 20m      5
# 10h 5m       5
# 32h 5m       5
# 30h 55m      5
# 28h 25m      5
# 7h 25m       5
# 13h 5m       5
# 15h 50m      5
# 28h 40m      5
# 3h 35m       5
# 4h 15m       4
# 24h 25m      4
# 21h 30m      4
# 22h 40m      4
# 28h 10m      4
# 23h 25m      4
# 24h 5m       4
# 38h 35m      4
# 26h 45m      4
# 21h 50m      4
# 16h 30m      3
# 25h 10m      3
# 27h 50m      3
# 18h 35m      3
# 4h 20m       3
# 17h 50m      3
# 12h 50m      3
# 30h          3
# 3h 50m       3
# 26h 5m       3
# 24h 20m      3
# 13h 40m      3
# 18h 15m      3
# 35h 5m       3
# 18h 40m      3
# 11h 10m      2
# 27h 25m      2
# 9h 55m       2
# 18h 55m      2
# 20h 5m       2
# 34h          2
# 32h 30m      2
# 6h 50m       2
# 34h 30m      2
# 34h 25m      2
# 19h 20m      2
# 20h 50m      2
# 19h 35m      2
# 7h 10m       2
# 31h 55m      2
# 28h 55m      2
# 3h 55m       2
# 20h 40m      2
# 35h 15m      2
# 34h 5m       2
# 31h 40m      2
# 30h 45m      2
# 17h 10m      2
# 39h 5m       2
# 29h 10m      1
# 31h 50m      1
# 42h 45m      1
# 29h 30m      1
# 37h 10m      1
# 27h 30m      1
# 33h 20m      1
# 3h 25m       1
# 41h 20m      1
# 35h 35m      1
# 35h 20m      1
# 32h 55m      1
# 19h 50m      1
# 33h 45m      1
# 47h          1
# 27h 55m      1
# 40h 20m      1
# 30h 25m      1
# 30h 15m      1
# 32h 20m      1
# 36h 25m      1
# 13h 35m      1
# 28h 30m      1
# 47h 40m      1
# 29h 40m      1
# 30h 10m      1
# 31h 30m      1
# 42h 5m       1
# 4h 10m       1
# 5m           1
# Name: count, dtype: int64
# --------------------------------------------------
# Check null value
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64
# --------------------------------------------------
# Drop null value rows
# --------------------------------------------------
# Check null values
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64
# --------------------------------------------------
# Fetch journey day and month from Date_of_Journey
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Day  Journey_Month
# 0           24              3
# 1            1              5
# 2            9              6
# 3           12              5
# 4            1              3
# --------------------------------------------------
# Fetch Departure hours and minutes from Dep_Time
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_Day  Journey_Month  Dep_hour  Dep_Minute
# 0           24              3        22          20
# 1            1              5         5          50
# 2            9              6         9          25
# 3           12              5        18           5
# 4            1              3        16          50
# --------------------------------------------------
# Drop Dep_time and Date_of_Journey columns
# --------------------------------------------------
# Fetch journey hours and minutes from Arrival_Time
# /tmp/ipykernel_12717/2314376658.py:33: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight_test['Dep_hour'] = pd.to_datetime(flight_test.Dep_Time ).dt.hour
# /tmp/ipykernel_12717/2314376658.py:34: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight_test['Dep_Minute'] = pd.to_datetime(flight_test.Dep_Time ).dt.minute
# /tmp/ipykernel_12717/2314376658.py:43: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight_test['Arrival_hour'] = pd.to_datetime(flight_test.Arrival_Time ).dt.hour
# /tmp/ipykernel_12717/2314376658.py:44: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   flight_test['Arrival_Minute'] = pd.to_datetime(flight_test.Arrival_Time ).dt.minute
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  Journey_Day  Journey_Month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            1              5
# 2      19h     2 stops         No info  13882            9              6
# 3   5h 25m      1 stop         No info   6218           12              5
# 4   4h 45m      1 stop         No info  13302            1              3
#
#    Dep_hour  Dep_Minute  Arrival_hour  Arrival_Minute
# 0        22          20             1              10
# 1         5          50            13              15
# 2         9          25             4              25
# 3        18           5            23              30
# 4        16          50            21              35
# --------------------------------------------------
# Drop Arrival_Time columns
# --------------------------------------------------
# Fetch  hours and minutes from Durations
# --------------------------------------------------
# Count Airline values
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64
# --------------------------------------------------
# OneHotEncoder on Airline Column
#    Air India  GoAir  IndiGo  Jet Airways  Jet Airways Business  \
# 0      False  False    True        False                 False
# 1       True  False   False        False                 False
# 2      False  False   False         True                 False
# 3      False  False    True        False                 False
# 4      False  False    True        False                 False
#
#    Multiple carriers  Multiple carriers Premium economy  SpiceJet  Trujet  \
# 0              False                              False     False   False
# 1              False                              False     False   False
# 2              False                              False     False   False
# 3              False                              False     False   False
# 4              False                              False     False   False
#
#    Vistara  Vistara Premium economy
# 0    False                    False
# 1    False                    False
# 2    False                    False
# 3    False                    False
# 4    False                    False
# --------------------------------------------------
# Count Source values
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64
# --------------------------------------------------
# Count Source values
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64
# --------------------------------------------------
# OneHotEncoder on Source Column
#    Source_Chennai  Source_Delhi  Source_Kolkata  Source_Mumbai
# 0           False         False           False          False
# 1           False         False            True          False
# 2           False          True           False          False
# 3           False         False            True          False
# 4           False         False           False          False
# --------------------------------------------------
# Count Destination values
# Destination
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64
# --------------------------------------------------
# OneHotEncoder on Destination Column
#    Destination_Cochin  Destination_Delhi  Destination_Hyderabad  \
# 0               False              False                  False
# 1               False              False                  False
# 2                True              False                  False
# 3               False              False                  False
# 4               False              False                  False
#
#    Destination_Kolkata  Destination_New Delhi
# 0                False                   True
# 1                False                  False
# 2                False                  False
# 3                False                  False
# 4                False                   True
# --------------------------------------------------
# Show route
# 0                                BLR → DEL
# 1                    CCU → IXR → BBI → BLR
# 2                    DEL → LKO → BOM → COK
# 3                          CCU → NAG → BLR
# 4                          BLR → NAG → DEL
# 5                                CCU → BLR
# 6                          BLR → BOM → DEL
# 7                          BLR → BOM → DEL
# 8                          BLR → BOM → DEL
# 9                          DEL → BOM → COK
# 10                         DEL → BLR → COK
# 11                               CCU → BLR
# 12                               MAA → CCU
# 13                         CCU → BOM → BLR
# 14                               CCU → BLR
# 15                   DEL → AMD → BOM → COK
# 16                         DEL → PNQ → COK
# 17                         DEL → BOM → COK
# 18                   DEL → CCU → BOM → COK
# 19                         DEL → BOM → COK
# 20                         DEL → BOM → COK
# 21                         BLR → COK → DEL
# 22                               BLR → DEL
# 23                               BLR → DEL
# 24                         CCU → BOM → BLR
# 25                   DEL → IDR → BOM → COK
# 26                         DEL → LKO → COK
# 27                         DEL → BOM → COK
# 28                               BLR → DEL
# 29                               MAA → CCU
# 30                               MAA → CCU
# 31                   CCU → GAU → DEL → BLR
# 32                               BLR → DEL
# 33                   DEL → NAG → BOM → COK
# 34                         DEL → BOM → COK
# 35                         DEL → BOM → COK
# 36                         CCU → MAA → BLR
# 37                               CCU → BLR
# 38                         BLR → BOM → DEL
# 39                         DEL → BOM → COK
# 40                         DEL → HYD → COK
# 41                         BLR → BOM → DEL
# 42                         DEL → BOM → COK
# 43                               BLR → DEL
# 44                         DEL → BOM → COK
# 45                               BLR → DEL
# 46                               BLR → DEL
# 47                               MAA → CCU
# 48                         CCU → HYD → BLR
# 49                   DEL → AMD → BOM → COK
# 50                               DEL → COK
# 51                         CCU → DEL → BLR
# 52                               BLR → DEL
# 53                               BLR → DEL
# 54                               BLR → DEL
# 55                         CCU → BOM → BLR
# 56                   BLR → BOM → AMD → DEL
# 57                               MAA → CCU
# 58                         DEL → BOM → COK
# 59                         BOM → DEL → HYD
# 60                         CCU → BOM → BLR
# 61                         DEL → MAA → COK
# 62                         DEL → BOM → COK
# 63                         DEL → BOM → COK
# 64                               MAA → CCU
# 65                         DEL → BOM → COK
# 66                               BLR → DEL
# 67                               BOM → HYD
# 68                   DEL → BHO → BOM → COK
# 69                               MAA → CCU
# 70                               BOM → HYD
# 71                         BLR → BOM → DEL
# 72                         DEL → BOM → COK
# 73                   DEL → AMD → BOM → COK
# 74                         DEL → BLR → COK
# 75                               BLR → DEL
# 76                               BLR → DEL
# 77                               BOM → HYD
# 78                         DEL → BOM → COK
# 79                               MAA → CCU
# 80                         CCU → BOM → BLR
# 81                               BLR → DEL
# 82                         CCU → BOM → BLR
# 83                         DEL → BOM → COK
# 84                         DEL → BOM → COK
# 85                         BLR → BOM → DEL
# 86                         DEL → MAA → COK
# 87                   DEL → JAI → BOM → COK
# 88                         CCU → BOM → BLR
# 89                         CCU → DEL → BLR
# 90                         DEL → HYD → COK
# 91                         DEL → BOM → COK
# 92                         BLR → BOM → DEL
# 93                   DEL → BHO → BOM → COK
# 94                               CCU → BLR
# 95                               MAA → CCU
# 96                               BLR → DEL
# 97                               BLR → DEL
# 98                               BOM → HYD
# 99                   DEL → ATQ → BOM → COK
# 100                        CCU → BOM → BLR
# 101                        CCU → BOM → BLR
# 102                        DEL → BOM → COK
# 103                        CCU → MAA → BLR
# 104                              BLR → DEL
# 105                  DEL → JAI → BOM → COK
# 106                        DEL → BOM → COK
# 107                        DEL → BOM → COK
# 108                  DEL → JDH → BOM → COK
# 109                  DEL → AMD → BOM → COK
# 110                        BLR → BOM → DEL
# 111                              BLR → DEL
# 112                        CCU → DEL → BLR
# 113                        DEL → BOM → COK
# 114                        DEL → BOM → COK
# 115                        DEL → HYD → COK
# 116                        DEL → MAA → COK
# 117                        DEL → BOM → COK
# 118                              BLR → DEL
# 119                        DEL → BOM → COK
# 120                              BLR → DEL
# 121                              BOM → HYD
# 122                        CCU → BOM → BLR
# 123                        DEL → BOM → COK
# 124                              MAA → CCU
# 125                  CCU → BBI → BOM → BLR
# 126                        CCU → BOM → BLR
# 127                        CCU → BOM → BLR
# 128                              BLR → DEL
# 129                              MAA → CCU
# 130                        BLR → MAA → DEL
# 131                        DEL → BOM → COK
# 132                              DEL → COK
# 133                              CCU → BLR
# 134                        DEL → BOM → COK
# 135                  DEL → AMD → BOM → COK
# 136                  DEL → NAG → BOM → COK
# 137                  DEL → GOI → BOM → COK
# 138                              BLR → DEL
# 139                        DEL → BOM → COK
# 140                        DEL → BOM → COK
# 141                        CCU → BOM → BLR
# 142                        DEL → MAA → COK
# 143                        DEL → HYD → COK
# 144                        DEL → HYD → COK
# 145                        CCU → BOM → BLR
# 146                  DEL → ATQ → BOM → COK
# 147                        DEL → MAA → COK
# 148                        DEL → BLR → COK
# 149                        DEL → BOM → COK
# 150                              CCU → BLR
# 151                  DEL → BDQ → BOM → COK
# 152                              BLR → DEL
# 153                        CCU → BOM → BLR
# 154                        CCU → BOM → BLR
# 155                  CCU → JAI → BOM → BLR
# 156                  DEL → ATQ → BOM → COK
# 157                              BLR → DEL
# 158                        CCU → BOM → BLR
# 159                        DEL → BOM → COK
# 160                        CCU → DEL → BLR
# 161                              BLR → DEL
# 162                        CCU → BBI → BLR
# 163                        DEL → HYD → COK
# 164                        DEL → PNQ → COK
# 165                        DEL → BOM → COK
# 166                              BOM → HYD
# 167                              BLR → DEL
# 168                        DEL → BOM → COK
# 169                              BLR → DEL
# 170                        DEL → BOM → COK
# 171                              DEL → COK
# 172                        CCU → DEL → BLR
# 173                        DEL → BOM → COK
# 174                        CCU → BOM → BLR
# 175                        CCU → BOM → BLR
# 176                        DEL → BOM → COK
# 177                        CCU → DEL → BLR
# 178                        CCU → BOM → BLR
# 179                        DEL → BOM → COK
# 180                        DEL → BOM → COK
# 181                              BOM → HYD
# 182                        DEL → BOM → COK
# 183                        CCU → BOM → BLR
# 184                              MAA → CCU
# 185                        DEL → PNQ → COK
# 186                        DEL → LKO → COK
# 187                        CCU → DEL → BLR
# 188                              CCU → BLR
# 189                              BLR → DEL
# 190                        BLR → HYD → DEL
# 191                        DEL → TRV → COK
# 192                        DEL → HYD → COK
# 193                              BLR → DEL
# 194                        BLR → BOM → DEL
# 195                              MAA → CCU
# 196                        CCU → BOM → BLR
# 197                        DEL → BOM → COK
# 198                              BLR → DEL
# 199                        DEL → BOM → COK
# 200                        CCU → BOM → BLR
# 201                              BLR → DEL
# 202                              DEL → COK
# 203                              DEL → COK
# 204                        DEL → BOM → COK
# 205                              BLR → DEL
# 206                        DEL → BOM → COK
# 207                              BLR → DEL
# 208                        CCU → BOM → BLR
# 209                  DEL → AMD → BOM → COK
# 210                              BLR → DEL
# 211                        DEL → MAA → COK
# 212                        DEL → HYD → COK
# 213                        DEL → BOM → COK
# 214                        DEL → BLR → COK
# 215                              BOM → HYD
# 216                        CCU → DEL → BLR
# 217                              BLR → DEL
# 218                              BLR → DEL
# 219                        DEL → BOM → COK
# 220                              BLR → DEL
# 221                        DEL → BOM → COK
# 222                              BOM → HYD
# 223                        DEL → BOM → COK
# 224                  DEL → JAI → BOM → COK
# 225                  DEL → CCU → BOM → COK
# 226                  DEL → IDR → BOM → COK
# 227                              BLR → DEL
# 228                              BOM → HYD
# 229                              BOM → HYD
# 230                        CCU → BOM → BLR
# 231                              CCU → BLR
# 232                        DEL → BOM → COK
# 233                        DEL → BOM → COK
# 234                        DEL → LKO → COK
# 235                              CCU → BLR
# 236                        DEL → BOM → COK
# 237                        DEL → BOM → COK
# 238                              BLR → DEL
# 239                        DEL → BOM → COK
# 240                        BLR → BOM → DEL
# 241                        CCU → BOM → BLR
# 242                        DEL → BOM → COK
# 243                              MAA → CCU
# 244                              MAA → CCU
# 245                              BLR → DEL
# 246                        DEL → BOM → COK
# 247                        DEL → BOM → COK
# 248                              MAA → CCU
# 249                        DEL → PNQ → COK
# 250                              DEL → COK
# 251                  DEL → AMD → BOM → COK
# 252                        CCU → BOM → BLR
# 253                        DEL → HYD → COK
# 254                        DEL → BOM → COK
# 255                              BOM → HYD
# 256                              BLR → DEL
# 257                              BLR → DEL
# 258                        DEL → BOM → COK
# 259                  DEL → JAI → BOM → COK
# 260                              BLR → DEL
# 261                              BLR → DEL
# 262                              CCU → BLR
# 263                        DEL → HYD → COK
# 264                  CCU → IXR → DEL → BLR
# 265                        DEL → BOM → COK
# 266                        DEL → BOM → COK
# 267                        CCU → BOM → BLR
# 268                              MAA → CCU
# 269                        BLR → BOM → DEL
# 270                        CCU → BOM → BLR
# 271                        DEL → HYD → COK
# 272                        DEL → BOM → COK
# 273                  DEL → IXU → BOM → COK
# 274                        DEL → MAA → COK
# 275                              BOM → HYD
# 276                              BOM → HYD
# 277                        CCU → IXB → BLR
# 278                        DEL → BLR → COK
# 279                              DEL → COK
# 280                        CCU → BOM → BLR
# 281                        DEL → MAA → COK
# 282                              BLR → DEL
# 283                        CCU → BOM → BLR
# 284                              CCU → BLR
# 285                        DEL → BOM → COK
# 286                              BLR → DEL
# 287                        DEL → BOM → COK
# 288                        DEL → BOM → COK
# 289                  BLR → BOM → JDH → DEL
# 290                        DEL → BOM → COK
# 291                  DEL → UDR → BOM → COK
# 292                        CCU → BOM → BLR
# 293                              BOM → HYD
# 294                              CCU → BLR
# 295                              BLR → DEL
# 296                        BLR → BOM → DEL
# 297                              MAA → CCU
# 298                        DEL → BOM → COK
# 299                              BLR → DEL
# 300                              BOM → HYD
# 301                              BLR → DEL
# 302                              CCU → BLR
# 303                  DEL → JAI → BOM → COK
# 304                  DEL → HYD → MAA → COK
# 305                        DEL → BOM → COK
# 306                        BLR → BOM → DEL
# 307                  DEL → HYD → MAA → COK
# 308                  DEL → GOI → BOM → COK
# 309                              CCU → BLR
# 310                        CCU → BOM → BLR
# 311                        DEL → BOM → COK
# 312                        CCU → BOM → BLR
# 313                        DEL → BOM → COK
# 314                              MAA → CCU
# 315                  DEL → JAI → BOM → COK
# 316                              MAA → CCU
# 317                        DEL → BOM → COK
# 318                        DEL → BOM → COK
# 319                              CCU → BLR
# 320                              BLR → DEL
# 321                        DEL → BOM → COK
# 322                              CCU → BLR
# 323                        BLR → MAA → DEL
# 324                        CCU → BOM → BLR
# 325                        DEL → BOM → COK
# 326                        DEL → BOM → COK
# 327                        DEL → BOM → COK
# 328                              BLR → DEL
# 329                        CCU → MAA → BLR
# 330                        CCU → BBI → BLR
# 331                        DEL → HYD → COK
# 332                              BLR → DEL
# 333                              CCU → BLR
# 334                              BLR → DEL
# 335                        CCU → DEL → BLR
# 336                  DEL → AMD → BOM → COK
# 337                  DEL → JDH → BOM → COK
# 338                              DEL → COK
# 339                        DEL → BOM → COK
# 340                              BLR → DEL
# 341                        DEL → BOM → COK
# 342                        CCU → DEL → BLR
# 343                  DEL → IDR → BOM → COK
# 344                  DEL → JDH → BOM → COK
# 345                              CCU → BLR
# 346                        DEL → BOM → COK
# 347                  DEL → IDR → BOM → COK
# 348                  CCU → BOM → COK → BLR
# 349                              BLR → DEL
# 350                              BLR → DEL
# 351                        DEL → BLR → COK
# 352                              CCU → BLR
# 353                        BLR → CCU → DEL
# 354                        DEL → BOM → COK
# 355                              BLR → DEL
# 356                        BLR → HYD → DEL
# 357                        DEL → BLR → COK
# 358                              BLR → DEL
# 359                        DEL → BOM → COK
# 360                              BLR → DEL
# 361                              CCU → BLR
# 362                              BLR → DEL
# 363                        BLR → MAA → DEL
# 364                        CCU → BOM → BLR
# 365                        DEL → TRV → COK
# 366                        DEL → HYD → COK
# 367                              MAA → CCU
# 368                        CCU → BBI → BLR
# 369                              BLR → DEL
# 370                              DEL → COK
# 371                        CCU → DEL → BLR
# 372                              BLR → DEL
# 373                              BLR → DEL
# 374                              BOM → HYD
# 375                        DEL → BOM → COK
# 376                        DEL → BOM → COK
# 377                        CCU → BOM → BLR
# 378                  CCU → BOM → GOI → BLR
# 379                        BLR → BOM → DEL
# 380                        DEL → BOM → COK
# 381                  DEL → JAI → BOM → COK
# 382                              BLR → DEL
# 383                        CCU → DEL → BLR
# 384                        DEL → BOM → COK
# 385                              MAA → CCU
# 386                        DEL → BOM → COK
# 387                              BOM → HYD
# 388                              CCU → BLR
# 389                        DEL → BOM → COK
# 390                  DEL → IDR → BOM → COK
# 391                        DEL → BLR → COK
# 392                        DEL → BOM → COK
# 393                        DEL → BOM → COK
# 394                        DEL → BOM → COK
# 395                              BLR → DEL
# 396                        DEL → BOM → COK
# 397                              MAA → CCU
# 398                              BLR → DEL
# 399                  CCU → BOM → GOI → BLR
# 400                        BLR → BOM → DEL
# 401                  DEL → IDR → BOM → COK
# 402            DEL → RPR → NAG → BOM → COK
# 403                              BLR → DEL
# 404                  DEL → CCU → BOM → COK
# 405                        CCU → BOM → BLR
# 406                  DEL → BHO → BOM → COK
# 407                              BLR → DEL
# 408                        DEL → BOM → COK
# 409                        DEL → BOM → COK
# 410                  DEL → HYD → BOM → COK
# 411                        CCU → BOM → BLR
# 412                        DEL → BOM → COK
# 413                        DEL → BOM → COK
# 414                              BLR → DEL
# 415                        CCU → DEL → BLR
# 416                        CCU → BOM → BLR
# 417                  DEL → JAI → BOM → COK
# 418                        DEL → BOM → COK
# 419                        DEL → BOM → COK
# 420                        DEL → HYD → COK
# 421                        CCU → BOM → BLR
# 422                              BOM → HYD
# 423                              BLR → DEL
# 424                              MAA → CCU
# 425                        DEL → BOM → COK
# 426                              BLR → DEL
# 427                        DEL → BOM → COK
# 428                              BLR → DEL
# 429                        CCU → DEL → BLR
# 430                              BLR → DEL
# 431                        DEL → BOM → COK
# 432                  CCU → DEL → AMD → BLR
# 433                              BLR → DEL
# 434                              BLR → DEL
# 435                        DEL → BOM → COK
# 436                        DEL → HYD → COK
# 437                              DEL → COK
# 438                        DEL → BOM → COK
# 439                        DEL → BOM → COK
# 440                              BLR → DEL
# 441                        CCU → BOM → BLR
# 442                        DEL → HYD → COK
# 443                        BLR → HYD → DEL
# 444                        CCU → BOM → BLR
# 445                              BLR → DEL
# 446                  DEL → CCU → BOM → COK
# 447                              MAA → CCU
# 448                        CCU → BOM → BLR
# 449                        CCU → BOM → BLR
# 450                        DEL → BOM → COK
# 451                  DEL → GOI → BOM → COK
# 452                  DEL → AMD → BOM → COK
# 453                              BLR → DEL
# 454                        DEL → HYD → COK
# 455                  DEL → GOI → BOM → COK
# 456                        DEL → BOM → COK
# 457                              MAA → CCU
# 458                        CCU → PNQ → BLR
# 459                        DEL → BOM → COK
# 460                        DEL → BOM → COK
# 461                              BLR → DEL
# 462                        DEL → BLR → COK
# 463                              BLR → DEL
# 464                              CCU → BLR
# 465                        CCU → BOM → BLR
# 466                              CCU → BLR
# 467                        DEL → BOM → COK
# 468                        DEL → BLR → COK
# 469                              BLR → DEL
# 470                  DEL → UDR → BOM → COK
# 471                        DEL → BOM → COK
# 472                        DEL → BOM → COK
# 473                        DEL → BOM → COK
# 474                              BLR → DEL
# 475                        DEL → BOM → COK
# 476                              BLR → DEL
# 477                        CCU → BOM → BLR
# 478                              BLR → DEL
# 479                        DEL → MAA → COK
# 480                        CCU → BOM → BLR
# 481                        DEL → BOM → COK
# 482                        CCU → PNQ → BLR
# 483                        DEL → BOM → COK
# 484                              CCU → BLR
# 485                              MAA → CCU
# 486                        BLR → BOM → DEL
# 487                        CCU → HYD → BLR
# 488                              MAA → CCU
# 489                  BLR → CCU → GAU → DEL
# 490                        BLR → CCU → DEL
# 491                        DEL → BOM → COK
# 492                  DEL → NAG → BOM → COK
# 493                        DEL → HYD → COK
# 494                        DEL → BLR → COK
# 495                        CCU → BOM → BLR
# 496                        DEL → BOM → COK
# 497                        DEL → BOM → COK
# 498                        CCU → DEL → BLR
# 499                  DEL → BDQ → BOM → COK
# 500                              BLR → DEL
# 501                              BOM → HYD
# 502                        DEL → BOM → COK
# 503                        DEL → BOM → COK
# 504                        DEL → BOM → COK
# 505                              BOM → HYD
# 506                        DEL → BOM → COK
# 507                              MAA → CCU
# 508                        CCU → DEL → BLR
# 509                  DEL → JAI → BOM → COK
# 510                        BLR → BOM → DEL
# 511                              BOM → HYD
# 512                        BLR → BOM → DEL
# 513                        CCU → BOM → BLR
# 514                  DEL → HYD → MAA → COK
# 515                  DEL → GOI → BOM → COK
# 516                              MAA → CCU
# 517                        DEL → BOM → COK
# 518                        DEL → BOM → COK
# 519                              BLR → DEL
# 520                  DEL → HYD → MAA → COK
# 521                        DEL → MAA → COK
# 522                        DEL → BLR → COK
# 523                              MAA → CCU
# 524                        BLR → BOM → DEL
# 525                  CCU → IXR → DEL → BLR
# 526                        DEL → BOM → COK
# 527                        DEL → BOM → COK
# 528                              BLR → DEL
# 529                              DEL → COK
# 530                  CCU → DEL → COK → BLR
# 531                        DEL → BLR → COK
# 532                        DEL → BOM → COK
# 533                        CCU → BOM → BLR
# 534                        CCU → DEL → BLR
# 535                        CCU → BOM → BLR
# 536                        BLR → BOM → DEL
# 537                              MAA → CCU
# 538                              BLR → DEL
# 539                              CCU → BLR
# 540                        CCU → MAA → BLR
# 541                              CCU → BLR
# 542                        DEL → BOM → COK
# 543                        CCU → BOM → BLR
# 544                        CCU → DEL → BLR
# 545                              BOM → HYD
# 546                        DEL → BOM → COK
# 547                              CCU → BLR
# 548                              BLR → DEL
# 549                        CCU → DEL → BLR
# 550                        DEL → HYD → COK
# 551                        DEL → BOM → COK
# 552                              MAA → CCU
# 553                  DEL → AMD → BOM → COK
# 554                              BLR → DEL
# 555                        CCU → DEL → BLR
# 556                              DEL → COK
# 557                              BLR → DEL
# 558                        CCU → DEL → BLR
# 559                        CCU → DEL → BLR
# 560                        CCU → BOM → BLR
# 561                              CCU → BLR
# 562                        DEL → BOM → COK
# 563                              DEL → COK
# 564                        CCU → DEL → BLR
# 565                        DEL → BOM → COK
# 566                        DEL → BOM → COK
# 567                              BLR → DEL
# 568                              CCU → BLR
# 569                              BOM → HYD
# 570                        CCU → DEL → BLR
# 571                        DEL → BLR → COK
# 572                              BLR → DEL
# 573                        CCU → BOM → BLR
# 574                        DEL → HYD → COK
# 575                              BLR → DEL
# 576                  DEL → CCU → BOM → COK
# 577                              CCU → BLR
# 578                        DEL → BOM → COK
# 579                        DEL → BOM → COK
# 580                              BLR → DEL
# 581                              DEL → COK
# 582                              CCU → BLR
# 583                        DEL → BOM → COK
# 584                              BOM → HYD
# 585                        DEL → HYD → COK
# 586                              BLR → DEL
# 587                        CCU → BOM → BLR
# 588                  DEL → AMD → BOM → COK
# 589                        BLR → BOM → DEL
# 590                        CCU → BOM → BLR
# 591                              BLR → DEL
# 592                              BLR → DEL
# 593                              BLR → DEL
# 594                        CCU → BOM → BLR
# 595                              MAA → CCU
# 596                        BLR → PNQ → DEL
# 597                  BOM → JDH → DEL → HYD
# 598                  DEL → JAI → BOM → COK
# 599                        DEL → MAA → COK
# 600                        DEL → BOM → COK
# 601                              CCU → BLR
# 602                        DEL → BOM → COK
# 603                        BLR → BOM → DEL
# 604                  DEL → NAG → BOM → COK
# 605                        BLR → COK → DEL
# 606                        CCU → BOM → BLR
# 607                              CCU → BLR
# 608                        CCU → BOM → BLR
# 609                        DEL → BOM → COK
# 610                              BLR → DEL
# 611                        DEL → BOM → COK
# 612                        DEL → BOM → COK
# 613                        DEL → BOM → COK
# 614                              CCU → BLR
# 615                        DEL → BOM → COK
# 616                              CCU → BLR
# 617                        DEL → BOM → COK
# 618                              BLR → DEL
# 619                        DEL → BOM → COK
# 620                  BLR → BOM → BHO → DEL
# 621                        BLR → HYD → DEL
# 622                              BLR → DEL
# 623                        CCU → DEL → BLR
# 624                        DEL → HYD → COK
# 625                        BLR → BOM → DEL
# 626                        CCU → DEL → BLR
# 627                        BLR → BOM → DEL
# 628                        BLR → BOM → DEL
# 629                        CCU → BOM → BLR
# 630                        BLR → HYD → DEL
# 631                              CCU → BLR
# 632                        CCU → DEL → BLR
# 633                              BLR → DEL
# 634                              BLR → DEL
# 635                              BOM → HYD
# 636                        DEL → BOM → COK
# 637                              BLR → DEL
# 638                        DEL → BOM → COK
# 639                              MAA → CCU
# 640                        CCU → BOM → BLR
# 641                              BLR → DEL
# 642                        CCU → BOM → BLR
# 643                  DEL → JAI → BOM → COK
# 644                        CCU → DEL → BLR
# 645                              BLR → DEL
# 646                  DEL → HYD → BOM → COK
# 647                        DEL → BOM → COK
# 648                              BOM → HYD
# 649                              MAA → CCU
# 650                        CCU → BBI → BLR
# 651                              BLR → DEL
# 652                        BLR → BOM → DEL
# 653                        DEL → BOM → COK
# 654                              BOM → HYD
# 655                              BOM → HYD
# 656                  CCU → GAU → DEL → BLR
# 657                        BLR → BOM → DEL
# 658                        DEL → BOM → COK
# 659                              BLR → DEL
# 660                        DEL → BOM → COK
# 661                        DEL → BOM → COK
# 662                        DEL → BOM → COK
# 663                              MAA → CCU
# 664                              BLR → DEL
# 665                  CCU → BOM → GOI → BLR
# 666                              BLR → DEL
# 667                  DEL → AMD → BOM → COK
# 668                        CCU → BOM → BLR
# 669                              BOM → HYD
# 670                        DEL → BOM → COK
# 671                        DEL → BOM → COK
# 672                  DEL → AMD → BOM → COK
# 673                  DEL → UDR → BOM → COK
# 674                        CCU → BOM → BLR
# 675                        CCU → MAA → BLR
# 676                              BLR → DEL
# 677                  DEL → IDR → BOM → COK
# 678                        CCU → DEL → BLR
# 679                              MAA → CCU
# 680                        DEL → BOM → COK
# 681                        DEL → BLR → COK
# 682                        CCU → BOM → BLR
# 683                  DEL → NAG → BOM → COK
# 684                              BLR → DEL
# 685                        DEL → AMD → COK
# 686                              MAA → CCU
# 687                        DEL → BOM → COK
# 688                              MAA → CCU
# 689                              BLR → DEL
# 690                              BOM → HYD
# 691                        DEL → HYD → COK
# 692                        CCU → DEL → BLR
# 693                        BLR → LKO → DEL
# 694                        CCU → DEL → BLR
# 695                        DEL → HYD → COK
# 696                        DEL → BOM → COK
# 697                              MAA → CCU
# 698                        DEL → BOM → COK
# 699                  DEL → ATQ → BOM → COK
# 700                        CCU → BOM → BLR
# 701                              BLR → DEL
# 702                  DEL → AMD → BOM → COK
# 703                              CCU → BLR
# 704                              BLR → DEL
# 705                              MAA → CCU
# 706                        CCU → GAU → BLR
# 707                        CCU → BOM → BLR
# 708                        DEL → BOM → COK
# 709                              BLR → DEL
# 710                        DEL → BOM → COK
# 711                              BOM → HYD
# 712                  DEL → AMD → BOM → COK
# 713                        CCU → BOM → BLR
# 714                              CCU → BLR
# 715                        DEL → HYD → COK
# 716                              MAA → CCU
# 717                        DEL → BOM → COK
# 718                              BOM → HYD
# 719                        CCU → DEL → BLR
# 720                  DEL → UDR → BOM → COK
# 721                        DEL → BOM → COK
# 722                        CCU → MAA → BLR
# 723                        DEL → BOM → COK
# 724                        DEL → MAA → COK
# 725                              CCU → BLR
# 726                        DEL → BOM → COK
# 727                        DEL → BOM → COK
# 728                  DEL → JAI → BOM → COK
# 729                        BOM → GOI → HYD
# 730                        DEL → BOM → COK
# 731                              BLR → DEL
# 732                        CCU → MAA → BLR
# 733                              MAA → CCU
# 734                              BOM → HYD
# 735                        CCU → MAA → BLR
# 736                              CCU → BLR
# 737                              CCU → BLR
# ...
# 10409                      CCU → DEL → BLR
# 10410                      DEL → BOM → COK
# 10411                      DEL → BOM → COK
# 10412                            BLR → DEL
# 10413                            BLR → DEL
# 10414                      CCU → BOM → BLR
# 10415                            BLR → DEL
# 10416                            CCU → BLR
# 10417                            BLR → DEL
# 10418                            MAA → CCU
# 10419                      DEL → MAA → COK
# 10420                DEL → AMD → BOM → COK
# 10421                      CCU → BOM → BLR
# 10422                      DEL → HYD → COK
# 10423                            BLR → DEL
# 10424                BLR → BOM → AMD → DEL
# 10425                            CCU → BLR
# 10426                            DEL → COK
# 10427                      BLR → BOM → DEL
# 10428                      CCU → DEL → BLR
# 10429                            CCU → BLR
# 10430                            BLR → DEL
# 10431                            CCU → BLR
# 10432                            BLR → DEL
# 10433                            BOM → HYD
# 10434                      DEL → BOM → COK
# 10435                      CCU → BBI → BLR
# 10436                      CCU → BOM → BLR
# 10437                      DEL → BOM → COK
# 10438                      CCU → KNU → BLR
# 10439                      BLR → BOM → DEL
# 10440                            BLR → DEL
# 10441                      BLR → BOM → DEL
# 10442                            BLR → DEL
# 10443                      DEL → BOM → COK
# 10444                      CCU → BOM → BLR
# 10445                DEL → JDH → BOM → COK
# 10446                            MAA → CCU
# 10447                      DEL → BLR → COK
# 10448                      DEL → BOM → COK
# 10449                      CCU → BOM → BLR
# 10450                      CCU → BOM → BLR
# 10451                      CCU → BOM → BLR
# 10452                DEL → AMD → BOM → COK
# 10453                DEL → JAI → BOM → COK
# 10454                      CCU → BOM → BLR
# 10455                            DEL → COK
# 10456                DEL → AMD → BOM → COK
# 10457                      DEL → BOM → COK
# 10458                      DEL → HYD → COK
# 10459                            BOM → HYD
# 10460                            BOM → HYD
# 10461                            CCU → BLR
# 10462                            BOM → HYD
# 10463                            BOM → HYD
# 10464                      BLR → BOM → DEL
# 10465                            BLR → DEL
# 10466                      DEL → BOM → COK
# 10467                            BLR → DEL
# 10468                            BLR → DEL
# 10469                            MAA → CCU
# 10470                            CCU → BLR
# 10471                      DEL → BLR → COK
# 10472                            BLR → DEL
# 10473                CCU → BBI → BOM → BLR
# 10474                DEL → NAG → BOM → COK
# 10475                DEL → LKO → BOM → COK
# 10476                      DEL → BOM → COK
# 10477                            BLR → DEL
# 10478                      DEL → MAA → COK
# 10479                CCU → BOM → GOI → BLR
# 10480                            BLR → DEL
# 10481                      DEL → MAA → COK
# 10482                      CCU → DEL → BLR
# 10483                DEL → BHO → BOM → COK
# 10484                      CCU → DEL → BLR
# 10485                            CCU → BLR
# 10486                      DEL → BOM → COK
# 10487                      DEL → BOM → COK
# 10488                            BLR → DEL
# 10489                            MAA → CCU
# 10490                            DEL → COK
# 10491                      DEL → BOM → COK
# 10492                      DEL → BOM → COK
# 10493                            BOM → HYD
# 10494                            DEL → COK
# 10495                DEL → BHO → BOM → COK
# 10496                            BLR → DEL
# 10497                DEL → JAI → BOM → COK
# 10498                      CCU → BOM → BLR
# 10499                            BLR → DEL
# 10500                      CCU → BOM → BLR
# 10501                      DEL → HYD → COK
# 10502                            BOM → HYD
# 10503                            BLR → DEL
# 10504                      DEL → BLR → COK
# 10505                      DEL → BOM → COK
# 10506                DEL → AMD → BOM → COK
# 10507                      CCU → BOM → BLR
# 10508                      DEL → BOM → COK
# 10509                            DEL → COK
# 10510                            BLR → DEL
# 10511                BLR → BOM → BHO → DEL
# 10512                            BLR → DEL
# 10513                            BOM → HYD
# 10514                      DEL → BOM → COK
# 10515                            BLR → DEL
# 10516                            CCU → BLR
# 10517                            BLR → DEL
# 10518                CCU → BBI → BOM → BLR
# 10519                            CCU → BLR
# 10520                      DEL → BOM → COK
# 10521                            CCU → BLR
# 10522                      DEL → BOM → COK
# 10523                            BOM → HYD
# 10524                      DEL → AMD → COK
# 10525                      DEL → BOM → COK
# 10526                DEL → JAI → BOM → COK
# 10527                      DEL → BOM → COK
# 10528                      DEL → HYD → COK
# 10529                            BLR → DEL
# 10530                      BLR → HYD → DEL
# 10531                            BOM → HYD
# 10532                            CCU → BLR
# 10533                            BLR → DEL
# 10534                            CCU → BLR
# 10535                      CCU → BOM → BLR
# 10536                      DEL → BOM → COK
# 10537                      DEL → BOM → COK
# 10538                      CCU → BOM → BLR
# 10539                CCU → BOM → GOI → BLR
# 10540                DEL → JAI → BOM → COK
# 10541                            BOM → HYD
# 10542                      CCU → BOM → BLR
# 10543                            CCU → BLR
# 10544                      DEL → BOM → COK
# 10545                            BLR → DEL
# 10546                      CCU → BOM → BLR
# 10547                DEL → JAI → BOM → COK
# 10548                DEL → AMD → BOM → COK
# 10549                      CCU → BBI → BLR
# 10550                            CCU → BLR
# 10551                DEL → CCU → BOM → COK
# 10552                      CCU → DEL → BLR
# 10553                      DEL → BOM → COK
# 10554                DEL → JAI → BOM → COK
# 10555                CCU → IXR → DEL → BLR
# 10556                      DEL → BOM → COK
# 10557                            BLR → DEL
# 10558                      DEL → BOM → COK
# 10559                      DEL → BOM → COK
# 10560                      CCU → BOM → BLR
# 10561                      BLR → BOM → DEL
# 10562                      CCU → DEL → BLR
# 10563                      CCU → BOM → BLR
# 10564                            BLR → DEL
# 10565                      CCU → BOM → BLR
# 10566                      DEL → MAA → COK
# 10567                      CCU → BOM → BLR
# 10568                            CCU → BLR
# 10569                            CCU → BLR
# 10570                CCU → BOM → COK → BLR
# 10571                CCU → BOM → AMD → BLR
# 10572                      DEL → BOM → COK
# 10573                DEL → AMD → BOM → COK
# 10574                      CCU → HYD → BLR
# 10575                      CCU → BOM → BLR
# 10576                            BOM → HYD
# 10577                CCU → BOM → COK → BLR
# 10578                      DEL → BOM → COK
# 10579                      DEL → BOM → COK
# 10580                      BLR → BOM → DEL
# 10581                      DEL → BOM → COK
# 10582                      CCU → BOM → BLR
# 10583                      DEL → BOM → COK
# 10584                      DEL → BOM → COK
# 10585                      CCU → IXB → BLR
# 10586                            BLR → DEL
# 10587                      DEL → BOM → COK
# 10588                            BOM → HYD
# 10589                DEL → IDR → BOM → COK
# 10590                            BLR → DEL
# 10591                DEL → ATQ → BOM → COK
# 10592                      CCU → BOM → BLR
# 10593                      DEL → PNQ → COK
# 10594                DEL → AMD → BOM → COK
# 10595                      DEL → BOM → COK
# 10596                      DEL → BOM → COK
# 10597                            BLR → DEL
# 10598                      DEL → BOM → COK
# 10599                DEL → AMD → BOM → COK
# 10600                      DEL → HYD → COK
# 10601                      DEL → BOM → COK
# 10602                DEL → AMD → BOM → COK
# 10603                      DEL → MAA → COK
# 10604                            BLR → DEL
# 10605                            BLR → DEL
# 10606                      CCU → BOM → BLR
# 10607                      DEL → BOM → COK
# 10608                      CCU → BOM → BLR
# 10609                            BOM → HYD
# 10610                            MAA → CCU
# 10611                            BOM → HYD
# 10612                      BLR → BOM → DEL
# 10613                            BLR → DEL
# 10614                      DEL → BOM → COK
# 10615                            BLR → DEL
# 10616                DEL → JAI → BOM → COK
# 10617                            BOM → HYD
# 10618                            BLR → DEL
# 10619                      DEL → LKO → COK
# 10620                            CCU → BLR
# 10621                            CCU → BLR
# 10622                CCU → GAU → DEL → BLR
# 10623                DEL → AMD → BOM → COK
# 10624                      CCU → DEL → BLR
# 10625                DEL → JDH → BOM → COK
# 10626                            BLR → DEL
# 10627                      CCU → BOM → BLR
# 10628                      CCU → IXB → BLR
# 10629                      DEL → HYD → COK
# 10630                      CCU → BOM → BLR
# 10631                      DEL → BLR → COK
# 10632                      CCU → DEL → BLR
# 10633                      DEL → BOM → COK
# 10634                DEL → JAI → BOM → COK
# 10635                      DEL → BOM → COK
# 10636                      CCU → BOM → BLR
# 10637                            BLR → DEL
# 10638                      BLR → BOM → DEL
# 10639          DEL → RPR → NAG → BOM → COK
# 10640                      DEL → BOM → COK
# 10641                            MAA → CCU
# 10642                CCU → JAI → BOM → BLR
# 10643                      DEL → BOM → COK
# 10644                      DEL → BOM → COK
# 10645                      DEL → BOM → COK
# 10646                DEL → IDR → BOM → COK
# 10647                            DEL → COK
# 10648                DEL → CCU → BOM → COK
# 10649                            CCU → BLR
# 10650                      CCU → DEL → BLR
# 10651                      DEL → BOM → COK
# 10652                      DEL → TRV → COK
# 10653                      CCU → BOM → BLR
# 10654                            BLR → DEL
# 10655                            BOM → HYD
# 10656                            BLR → DEL
# 10657                      CCU → BOM → BLR
# 10658                            BLR → DEL
# 10659                            BLR → DEL
# 10660                            BLR → DEL
# 10661                      DEL → BOM → COK
# 10662                CCU → BOM → GOI → BLR
# 10663                DEL → JAI → BOM → COK
# 10664                            BLR → DEL
# 10665                            CCU → BLR
# 10666                      DEL → BOM → COK
# 10667                      BLR → BOM → DEL
# 10668                DEL → JDH → BOM → COK
# 10669                      DEL → BOM → COK
# 10670                CCU → IXR → DEL → BLR
# 10671                            BOM → HYD
# 10672                DEL → AMD → BOM → COK
# 10673                DEL → AMD → BOM → COK
# 10674                      BLR → BOM → DEL
# 10675                            BOM → HYD
# 10676                      DEL → BOM → COK
# 10677                            BLR → DEL
# 10678                            CCU → BLR
# 10679                            CCU → BLR
# 10680                            BLR → DEL
# 10681                            BLR → DEL
# 10682                DEL → GOI → BOM → COK
# Name: Route, dtype: object
# --------------------------------------------------
# Drop Route and Additional_Info
# --------------------------------------------------
# Cout Total_Stops
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64
# --------------------------------------------------
# Normalize total stops
# --------------------------------------------------
# Concate flight, airline, source and destionation
# --------------------------------------------------
# Show all rows and columns
# --------------------------------------------------
# Drop Airline, Source and Destination
# --------------------------------------------------
# Show head
#    Total_Stops  Price  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0            0   3897           24              3        22          20
# 1            2   7662            1              5         5          50
# 2            2  13882            9              6         9          25
# 3            1   6218           12              5        18           5
# 4            1  13302            1              3        16          50
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute  Air India  \
# 0             1              10              2               50      False
# 1            13              15              7               25       True
# 2             4              25             19                0      False
# 3            23              30              5               25      False
# 4            21              35              4               45      False
#
#    GoAir  IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0  False    True        False                 False              False
# 1  False   False        False                 False              False
# 2  False   False         True                 False              False
# 3  False    True        False                 False              False
# 4  False    True        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  \
# 0                              False     False   False    False
# 1                              False     False   False    False
# 2                              False     False   False    False
# 3                              False     False   False    False
# 4                              False     False   False    False
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False         False           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False         False            True
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False               False              False
# 1          False               False              False
# 2          False                True              False
# 3          False               False              False
# 4          False               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True
# --------------------------------------------------
# Shape
# (10682, 30)
# /tmp/ipykernel_12717/2314376658.py:124: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   flight_test.replace( { 'non-stop':0 , '1 stop':1 , '2 stops':2 , '3 stops':3 ,'4 stops':4 } ,inplace=True)

# %%
flight_test.head()
# Out:
#    Total_Stops  Price  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0            0   3897           24              3        22          20
# 1            2   7662            1              5         5          50
# 2            2  13882            9              6         9          25
# 3            1   6218           12              5        18           5
# 4            1  13302            1              3        16          50
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute  Air India  \
# 0             1              10              2               50      False
# 1            13              15              7               25       True
# 2             4              25             19                0      False
# 3            23              30              5               25      False
# 4            21              35              4               45      False
#
#    GoAir  IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0  False    True        False                 False              False
# 1  False   False        False                 False              False
# 2  False   False         True                 False              False
# 3  False    True        False                 False              False
# 4  False    True        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  \
# 0                              False     False   False    False
# 1                              False     False   False    False
# 2                              False     False   False    False
# 3                              False     False   False    False
# 4                              False     False   False    False
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False         False           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False         False            True
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False               False              False
# 1          False               False              False
# 2          False                True              False
# 3          False               False              False
# 4          False               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True

# %%
flight.head()
# Out:
#    Total_Stops  Price  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0            0   3897           24              3        22          20
# 1            2   7662            1              5         5          50
# 2            2  13882            9              6         9          25
# 3            1   6218           12              5        18           5
# 4            1  13302            1              3        16          50
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute  Air India  \
# 0             1              10              2               50      False
# 1            13              15              7               25       True
# 2             4              25             19                0      False
# 3            23              30              5               25      False
# 4            21              35              4               45      False
#
#    GoAir  IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0  False    True        False                 False              False
# 1  False   False        False                 False              False
# 2  False   False         True                 False              False
# 3  False    True        False                 False              False
# 4  False    True        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  \
# 0                              False     False   False    False
# 1                              False     False   False    False
# 2                              False     False   False    False
# 3                              False     False   False    False
# 4                              False     False   False    False
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False         False           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False         False            True
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False               False              False
# 1          False               False              False
# 2          False                True              False
# 3          False               False              False
# 4          False               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True

# %% [markdown]
# ## Feature selection

# %%
flight.shape , flight_test.shape
# Out:
# ((10682, 30), (10682, 30))

# %%
X = flight.drop(columns='Price',axis=1)
y = flight['Price']
X.head()
# Out:
#    Total_Stops  Journey_Day  Journey_Month  Dep_hour  Dep_Minute  \
# 0            0           24              3        22          20
# 1            2            1              5         5          50
# 2            2            9              6         9          25
# 3            1           12              5        18           5
# 4            1            1              3        16          50
#
#    Arrival_hour  Arrival_Minute  Duration_Hour  Duration_Minute  Air India  \
# 0             1              10              2               50      False
# 1            13              15              7               25       True
# 2             4              25             19                0      False
# 3            23              30              5               25      False
# 4            21              35              4               45      False
#
#    GoAir  IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0  False    True        False                 False              False
# 1  False   False        False                 False              False
# 2  False   False         True                 False              False
# 3  False    True        False                 False              False
# 4  False    True        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  \
# 0                              False     False   False    False
# 1                              False     False   False    False
# 2                              False     False   False    False
# 3                              False     False   False    False
# 4                              False     False   False    False
#
#    Vistara Premium economy  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                    False           False         False           False
# 1                    False           False         False            True
# 2                    False           False          True           False
# 3                    False           False         False            True
# 4                    False           False         False           False
#
#    Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0          False               False              False
# 1          False               False              False
# 2          False                True              False
# 3          False               False              False
# 4          False               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 2                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True

# %%
y.head()
# Out:
# 0     3897
# 1     7662
# 2    13882
# 3     6218
# 4    13302
# Name: Price, dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(flight.corr() , annot=True , cmap = 'RdYlGn')
plt.show()

# %%
# !pip install scikit-learn
from sklearn.ensemble import ExtraTreesRegressor
etr = ExtraTreesRegressor()
etr.fit(X,y)
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#      |████████████████████████████████| 13.3 MB 257 kB/s eta 0:00:01    |▍                               | 153 kB 1.0 MB/s eta 0:00:13     |██████████████████████▊         | 9.5 MB 427 kB/s eta 0:00:09     |███████████████████████████▊    | 11.6 MB 986 kB/s eta 0:00:02     |█████████████████████████████▉  | 12.4 MB 1.7 MB/s eta 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 3.0 MB/s eta 0:00:01
# Collecting scipy>=1.6.0
#   Downloading scipy-1.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#      |████████████████████████████████| 41.2 MB 4.2 kB/s eta 0:00:01     |████████                        | 10.2 MB 178 kB/s eta 0:02:54     |████████                        | 10.3 MB 178 kB/s eta 0:02:54     |█████████████▋                  | 17.5 MB 1.3 MB/s eta 0:00:19     |█████████████████████▌          | 27.6 MB 2.8 MB/s eta 0:00:05
# Requirement already satisfied: numpy>=1.19.5 in /home/akanksh/.local/lib/python3.11/site-packages (from scikit-learn) (2.1.1)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.2 scipy-1.14.1 threadpoolctl-3.5.0
# ExtraTreesRegressor()

# %%
plt.figure(figsize=(20,20))

feat = pd.Series(etr.feature_importances_ , index=X.columns)
feat.nlargest(20).plot(kind='barh')

plt.show()

# %% [markdown]
# ## Fit model using Random Forest

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2 , random_state=51)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor()
rfr.fit(X_train , y_train)
# Out:
# RandomForestRegressor()

# %%
pred = rfr.predict(X_test)

# %%
rfr.score(X_train , y_train)
# Out:
# 0.9533602860653038

# %%
rfr.score(X_test , y_test)
# Out:
# 0.8291059476773195

# %%
sns.distplot(y_test - pred)
# Out:
# /tmp/ipykernel_12717/2485339681.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test - pred)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
plt.scatter(y_test , pred , alpha=0.8)
plt.xlabel('y_test')
plt.ylabel('pred')
# Out:
# Text(0, 0.5, 'pred')

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 1130.5819739386984
# MSE: 3203630.419507498
# RMSE: 1789.868827458453

# %%
metrics.r2_score(y_test,pred)
# Out:
# 0.8291059476773195

# %% [markdown]
# ## Hyperprameter Tuning

# %%
from sklearn.model_selection import RandomizedSearchCV

n_estimators = [int(x) for x in np.linspace(100,2000,10)]
max_depth = [int(x) for x in np.linspace(100,2000,10)]
min_samples_split=[2,4,6,8,10,12,14]
min_samples_leaf=[1,3,5,7,8,10]
max_features=['sqrt','log2','auto',None]

random_search = {
    'n_estimators' : n_estimators,
    'max_depth' : max_depth,
    'min_samples_split' : min_samples_split,
    'min_samples_leaf' : min_samples_leaf,
    'max_features' : max_features,
    
}

random_search
# Out:
# {'n_estimators': [100, 311, 522, 733, 944, 1155, 1366, 1577, 1788, 2000],
#  'max_depth': [100, 311, 522, 733, 944, 1155, 1366, 1577, 1788, 2000],
#  'min_samples_split': [2, 4, 6, 8, 10, 12, 14],
#  'min_samples_leaf': [1, 3, 5, 7, 8, 10],
#  'max_features': ['sqrt', 'log2', 'auto', None]}

# %%
rfr_random = RandomizedSearchCV(estimator=rfr , param_distributions=random_search , n_iter=10 , cv=5 , verbose=2 , random_state=51 , n_jobs=1)

# %%
rfr_random.fit(X_train , y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=2000, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  21.7s
# [CV] END max_depth=2000, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  21.1s
# [CV] END max_depth=2000, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  17.3s
# [CV] END max_depth=2000, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  16.4s
# [CV] END max_depth=2000, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  16.9s
# [CV] END max_depth=311, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1155; total time=  20.3s
# [CV] END max_depth=311, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1155; total time=  19.7s
# [CV] END max_depth=311, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1155; total time=  21.4s
# [CV] END max_depth=311, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1155; total time=  20.5s
# [CV] END max_depth=311, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=1155; total time=  20.1s
# [CV] END max_depth=311, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   1.2s
# [CV] END max_depth=311, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   1.4s
# [CV] END max_depth=311, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   1.4s
# [CV] END max_depth=311, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   1.4s
# [CV] END max_depth=311, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=100; total time=   1.3s
# [CV] END max_depth=2000, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=2000; total time=   0.0s
# [CV] END max_depth=2000, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=2000; total time=   0.0s
# [CV] END max_depth=2000, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=2000; total time=   0.0s
# [CV] END max_depth=2000, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=2000; total time=   0.0s
# [CV] END max_depth=2000, max_features=auto, min_samples_leaf=10, min_samples_split=4, n_estimators=2000; total time=   0.0s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  16.9s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  17.5s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  17.8s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  17.5s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=1788; total time=  17.6s
# [CV] END max_depth=522, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.6s
# [CV] END max_depth=522, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.5s
# [CV] END max_depth=522, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.6s
# [CV] END max_depth=522, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.4s
# [CV] END max_depth=522, max_features=None, min_samples_leaf=3, min_samples_split=10, n_estimators=100; total time=   3.4s
# [CV] END max_depth=1577, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1577; total time=   0.0s
# [CV] END max_depth=1577, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1577; total time=   0.0s
# [CV] END max_depth=1577, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1577; total time=   0.0s
# [CV] END max_depth=1577, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1577; total time=   0.0s
# [CV] END max_depth=1577, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1577; total time=   0.0s
# [CV] END max_depth=1788, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=1788; total time=  52.2s
# [CV] END max_depth=1788, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=1788; total time=  50.1s
# [CV] END max_depth=1788, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=1788; total time=  51.2s
# [CV] END max_depth=1788, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=1788; total time=  53.5s
# [CV] END max_depth=1788, max_features=None, min_samples_leaf=5, min_samples_split=14, n_estimators=1788; total time=  53.1s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1366; total time=  12.4s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1366; total time=  13.0s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1366; total time=  12.9s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1366; total time=  12.5s
# [CV] END max_depth=1577, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1366; total time=  11.6s
# [CV] END max_depth=944, max_features=log2, min_samples_leaf=1, min_samples_split=12, n_estimators=1366; total time=  13.6s
# [CV] END max_depth=944, max_features=log2, min_samples_leaf=1, min_samples_split=12, n_estimators=1366; total time=  14.2s
# [CV] END max_depth=944, max_features=log2, min_samples_leaf=1, min_samples_split=12, n_estimators=1366; total time=  13.6s
# [CV] END max_depth=944, max_features=log2, min_samples_leaf=1, min_samples_split=12, n_estimators=1366; total time=  13.4s
# [CV] END max_depth=944, max_features=log2, min_samples_leaf=1, min_samples_split=12, n_estimators=1366; total time=  13.3s
# /home/akanksh/.local/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 10 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/akanksh/.local/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/akanksh/.local/lib/python3.11/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/home/akanksh/.local/lib/python3.11/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/home/akanksh/.local/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/akanksh/.local/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.72237075 0.78663829 0.77010832        nan 0.7213809  0.80403922
#         nan 0.78346537 0.70473672 0.78841357]
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [100, 311, 522, 733, 944,
#                                                       1155, 1366, 1577, 1788,
#                                                       2000],
#                                         'max_features': ['sqrt', 'log2', 'auto',
#                                                          None],
#                                         'min_samples_leaf': [1, 3, 5, 7, 8, 10],
#                                         'min_samples_split': [2, 4, 6, 8, 10,
#                                                               12, 14],
#                                         'n_estimators': [100, 311, 522, 733,
#                                                          944, 1155, 1366, 1577,
#                                                          1788, 2000]},
#                    random_state=51, verbose=2)

# %%
rfr_random.best_params_
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 10,
#  'min_samples_leaf': 3,
#  'max_features': None,
#  'max_depth': 522}

# %%
prediction = rfr_random.predict(X_test)

# %%
plt.figure(figsize = (8,8))
sns.distplot(y_test-prediction)
plt.show()
# Out:
# /tmp/ipykernel_12717/375150797.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-prediction)

# %%
plt.scatter(y_test , pred , alpha=0.8)
plt.xlabel('y_test')
plt.ylabel('pred')
# Out:
# Text(0, 0.5, 'pred')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 1086.914255739895
# MSE: 2664901.6943910853
# RMSE: 1632.452662220588

# %%
metrics.r2_score(y_test,prediction)
# Out:
# 0.8578438240494413

# %% [markdown]
# ## Save the model

# %%
import pickle
file = open('Flight-Fare-Prediction.pkl','wb')
pickle.dump(rfr_random,file)

# %%
model = open('Flight-Fare-Prediction.pkl','rb')
mod = pickle.load(model)

# %%
predicted_data = mod.predict(X_test)

# %%
metrics.r2_score(y_test,predicted_data)
# Out:
# 0.8578438240494413
